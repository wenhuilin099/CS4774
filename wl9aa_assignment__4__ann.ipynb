# %% [markdown]
# # Assignment 4: Benchmarking Neural Nets with the XOR Problem

# %% [markdown]
# ### CS 4774 Machine Learning - Department of Computer Science - University of Virginia
# In this assignment, you will implement your own neural networks to classify non-linear data from the XOR dataset. For references, you may refer to my [lecture 13](https://docs.google.com/presentation/d/1otQfmMomWctLZKI3hHKAA4lLkbXFtagLaQov8gNh4LI/edit?usp=sharing) and [Colab Notebook 10](https://colab.research.google.com/drive/1x5biI3dP5YvvDEI0wapJcSgQNnATDzNe) if you need additional sample codes to help with your assignment. For deliverables, you must write code in Python/Tensorflow and submit **this** Jupyter Notebook file (.ipynb) to earn a total of 100 pts. Note that you must save your Notebook filename under this format: **yourUvaUserId_assignment_4_ann.ipynb**.

# %%
# You might want to use the following packages
import sklearn
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np
np.random.seed(42)

import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## 1. THE DATASET AND VISUALIZATION
#
# We will use the non-linear toy data called the XOR dataset. You may use the code snippet below to generate the train/validate/test set. Feel free to change the number of samples, and noise level. To keep the ratio between the sets consistent, please do not change the test_size and random_state parameters.

# %%
def make_xor(n_points):
    centers = np.array([[0,0],[0,1],[1,0],[1,1]])
    labels = np.array([0,1,1,0])
    data = np.array([]).reshape(-1,3)
    for center, label in zip(centers,labels):
        points = np.random.normal(loc=center,scale=0.2,size=(n_points//4,2))
        points_labels = np.hstack((points,label*np.ones(n_points//4).reshape((-1, 1))))
        data = np.vstack((data,points_labels))
    return (data[:,[0,1]],data[:,2])


X, y = make_xor(1000)
y=y.astype(np.int64)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=49)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size= 0.1, random_state=49) 
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)
# Out:
# (720, 2)
# (200, 2)
# (80, 2)

# %%
print(X_train)
print(X_train.dtype)
# Out:
# [[ 0.32899354 -0.04980721]
#  [-0.30510503  0.86161839]
#  [ 0.93593054  0.08483319]
#  ...
#  [-0.09707271  0.01637483]
#  [ 1.32668631 -0.22926908]
#  [ 0.79993374  0.86445101]]
# float64

# %% [markdown]
# ---
# ## 2. TRAIN A SIMPLE ANN FOR CLASSIFICATION TASK
#
# Use the standard libarary of Neural Net on the training data, and then test the classifier on the test data. You will create a simple ANN with 3 layers: an Input Layer, a Hidden Layer and an Output Layer. For each layer, you can specify the number of nodes appropriate for the XOR problem. Also, feel free to tune the network as you see fit. You have to report the accuracy of the network on the validation set.

# %%
import tensorflow as tf
from tensorflow import keras

my_model = keras.Sequential()
# Your code here!
my_model.add(keras.layers.Flatten(input_shape=[2]))
my_model.add(keras.layers.Dense(300, activation="relu"))
my_model.add(keras.layers.Dense(300, activation="softmax"))

# %%
my_model.layers
# Out:
# [<keras.layers.reshaping.flatten.Flatten at 0x7fa46ceafe10>,
#  <keras.layers.core.dense.Dense at 0x7fa46ceaf110>,
#  <keras.layers.core.dense.Dense at 0x7fa40db0c150>]

# %%
my_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2)                 0
#
#  dense (Dense)               (None, 300)               900
#
#  dense_1 (Dense)             (None, 300)               90300
#
# =================================================================
# Total params: 91,200
# Trainable params: 91,200
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(my_model, "my_mnist_model.png", show_shapes=True)

# %%
hidden = my_model.layers[1]
hidden.name
# Out:
# 'dense'

# %%
my_model.compile(loss="sparse_categorical_crossentropy" ,
              optimizer="sgd",
              metrics=["accuracy"])

# %%
X_val.shape
# Out:
# (80, 2)

# %%
y_val.shape
# Out:
# (80,)

# %%
my_model.fit(X_train, y_train, batch_size=100, epochs=200)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0890 - accuracy: 0.9806
# Epoch 2/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0888 - accuracy: 0.9806
# Epoch 3/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0887 - accuracy: 0.9819
# Epoch 4/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0886 - accuracy: 0.9806
# Epoch 5/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0885 - accuracy: 0.9806
# Epoch 6/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0883 - accuracy: 0.9806
# Epoch 7/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0883 - accuracy: 0.9806
# Epoch 8/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0881 - accuracy: 0.9806
# Epoch 9/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0879 - accuracy: 0.9806
# Epoch 10/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0878 - accuracy: 0.9806
# Epoch 11/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0877 - accuracy: 0.9806
# Epoch 12/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0876 - accuracy: 0.9806
# Epoch 13/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0875 - accuracy: 0.9806
# Epoch 14/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0873 - accuracy: 0.9819
# Epoch 15/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0872 - accuracy: 0.9819
# Epoch 16/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0871 - accuracy: 0.9806
# Epoch 17/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0870 - accuracy: 0.9806
# Epoch 18/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0869 - accuracy: 0.9806
# Epoch 19/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0867 - accuracy: 0.9806
# Epoch 20/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0866 - accuracy: 0.9806
# Epoch 21/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0865 - accuracy: 0.9806
# Epoch 22/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0864 - accuracy: 0.9806
# Epoch 23/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0863 - accuracy: 0.9806
# Epoch 24/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0862 - accuracy: 0.9806
# Epoch 25/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0861 - accuracy: 0.9806
# Epoch 26/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0860 - accuracy: 0.9819
# Epoch 27/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0859 - accuracy: 0.9819
# Epoch 28/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0857 - accuracy: 0.9819
# Epoch 29/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0857 - accuracy: 0.9806
# Epoch 30/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0855 - accuracy: 0.9806
# Epoch 31/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0854 - accuracy: 0.9806
# Epoch 32/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0853 - accuracy: 0.9819
# Epoch 33/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0851 - accuracy: 0.9806
# Epoch 34/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0850 - accuracy: 0.9806
# Epoch 35/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0849 - accuracy: 0.9806
# Epoch 36/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0848 - accuracy: 0.9806
# Epoch 37/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0847 - accuracy: 0.9806
# Epoch 38/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0846 - accuracy: 0.9806
# Epoch 39/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0845 - accuracy: 0.9806
# Epoch 40/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0844 - accuracy: 0.9806
# Epoch 41/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0843 - accuracy: 0.9806
# Epoch 42/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0842 - accuracy: 0.9806
# Epoch 43/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0841 - accuracy: 0.9806
# Epoch 44/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0839 - accuracy: 0.9819
# Epoch 45/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0838 - accuracy: 0.9819
# Epoch 46/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0837 - accuracy: 0.9819
# Epoch 47/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0836 - accuracy: 0.9819
# Epoch 48/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0835 - accuracy: 0.9833
# Epoch 49/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9819
# Epoch 50/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0834 - accuracy: 0.9833
# Epoch 51/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0832 - accuracy: 0.9819
# Epoch 52/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0831 - accuracy: 0.9819
# Epoch 53/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0830 - accuracy: 0.9819
# Epoch 54/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0829 - accuracy: 0.9819
# Epoch 55/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0828 - accuracy: 0.9819
# Epoch 56/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0827 - accuracy: 0.9819
# Epoch 57/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0826 - accuracy: 0.9819
# Epoch 58/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0825 - accuracy: 0.9819
# Epoch 59/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0824 - accuracy: 0.9819
# Epoch 60/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0823 - accuracy: 0.9819
# Epoch 61/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0821 - accuracy: 0.9819
# Epoch 62/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0821 - accuracy: 0.9819
# Epoch 63/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0819 - accuracy: 0.9819
# Epoch 64/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0819 - accuracy: 0.9819
# Epoch 65/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0818 - accuracy: 0.9819
# Epoch 66/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0817 - accuracy: 0.9819
# Epoch 67/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0816 - accuracy: 0.9806
# Epoch 68/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0815 - accuracy: 0.9819
# Epoch 69/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0814 - accuracy: 0.9819
# Epoch 70/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0813 - accuracy: 0.9819
# Epoch 71/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0812 - accuracy: 0.9819
# Epoch 72/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0811 - accuracy: 0.9819
# Epoch 73/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0810 - accuracy: 0.9819
# Epoch 74/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0809 - accuracy: 0.9819
# Epoch 75/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0808 - accuracy: 0.9819
# Epoch 76/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0808 - accuracy: 0.9819
# Epoch 77/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9819
# Epoch 78/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0805 - accuracy: 0.9819
# Epoch 79/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0805 - accuracy: 0.9819
# Epoch 80/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0803 - accuracy: 0.9819
# Epoch 81/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0803 - accuracy: 0.9819
# Epoch 82/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0801 - accuracy: 0.9819
# Epoch 83/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0800 - accuracy: 0.9819
# Epoch 84/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0799 - accuracy: 0.9819
# Epoch 85/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0799 - accuracy: 0.9819
# Epoch 86/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0798 - accuracy: 0.9819
# Epoch 87/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0797 - accuracy: 0.9819
# Epoch 88/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0796 - accuracy: 0.9819
# Epoch 89/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0795 - accuracy: 0.9819
# Epoch 90/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0794 - accuracy: 0.9819
# Epoch 91/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0793 - accuracy: 0.9819
# Epoch 92/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0792 - accuracy: 0.9819
# Epoch 93/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0791 - accuracy: 0.9819
# Epoch 94/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0790 - accuracy: 0.9819
# Epoch 95/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0789 - accuracy: 0.9819
# Epoch 96/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0788 - accuracy: 0.9819
# Epoch 97/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0788 - accuracy: 0.9819
# Epoch 98/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0787 - accuracy: 0.9819
# Epoch 99/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0786 - accuracy: 0.9819
# Epoch 100/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0785 - accuracy: 0.9819
# Epoch 101/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0784 - accuracy: 0.9819
# Epoch 102/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0783 - accuracy: 0.9819
# Epoch 103/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0782 - accuracy: 0.9806
# Epoch 104/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0781 - accuracy: 0.9819
# Epoch 105/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0780 - accuracy: 0.9819
# Epoch 106/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0779 - accuracy: 0.9819
# Epoch 107/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0779 - accuracy: 0.9819
# Epoch 108/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9819
# Epoch 109/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0776 - accuracy: 0.9819
# Epoch 110/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0776 - accuracy: 0.9819
# Epoch 111/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0775 - accuracy: 0.9819
# Epoch 112/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0774 - accuracy: 0.9806
# Epoch 113/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0773 - accuracy: 0.9819
# Epoch 114/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0772 - accuracy: 0.9819
# Epoch 115/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0772 - accuracy: 0.9819
# Epoch 116/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0771 - accuracy: 0.9819
# Epoch 117/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9819
# Epoch 118/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0769 - accuracy: 0.9819
# Epoch 119/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0768 - accuracy: 0.9819
# Epoch 120/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0767 - accuracy: 0.9819
# Epoch 121/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0766 - accuracy: 0.9819
# Epoch 122/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0766 - accuracy: 0.9806
# Epoch 123/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0765 - accuracy: 0.9819
# Epoch 124/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0764 - accuracy: 0.9819
# Epoch 125/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0763 - accuracy: 0.9819
# Epoch 126/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0762 - accuracy: 0.9819
# Epoch 127/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9819
# Epoch 128/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0761 - accuracy: 0.9819
# Epoch 129/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0760 - accuracy: 0.9819
# Epoch 130/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.9819
# Epoch 131/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0758 - accuracy: 0.9819
# Epoch 132/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9819
# Epoch 133/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9819
# Epoch 134/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0756 - accuracy: 0.9819
# Epoch 135/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0755 - accuracy: 0.9819
# Epoch 136/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0754 - accuracy: 0.9819
# Epoch 137/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0753 - accuracy: 0.9819
# Epoch 138/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0752 - accuracy: 0.9819
# Epoch 139/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0752 - accuracy: 0.9819
# Epoch 140/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0751 - accuracy: 0.9819
# Epoch 141/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0750 - accuracy: 0.9819
# Epoch 142/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0749 - accuracy: 0.9819
# Epoch 143/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0748 - accuracy: 0.9819
# Epoch 144/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0748 - accuracy: 0.9819
# Epoch 145/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0747 - accuracy: 0.9819
# Epoch 146/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0746 - accuracy: 0.9819
# Epoch 147/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0745 - accuracy: 0.9819
# Epoch 148/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0745 - accuracy: 0.9819
# Epoch 149/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0745 - accuracy: 0.9819
# Epoch 150/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0744 - accuracy: 0.9819
# Epoch 151/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0742 - accuracy: 0.9819
# Epoch 152/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0741 - accuracy: 0.9819
# Epoch 153/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0741 - accuracy: 0.9819
# Epoch 154/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0740 - accuracy: 0.9819
# Epoch 155/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0740 - accuracy: 0.9819
# Epoch 156/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0738 - accuracy: 0.9819
# Epoch 157/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0738 - accuracy: 0.9819
# Epoch 158/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0737 - accuracy: 0.9819
# Epoch 159/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0736 - accuracy: 0.9819
# Epoch 160/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0736 - accuracy: 0.9819
# Epoch 161/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0735 - accuracy: 0.9819
# Epoch 162/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0734 - accuracy: 0.9819
# Epoch 163/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0733 - accuracy: 0.9819
# Epoch 164/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0732 - accuracy: 0.9819
# Epoch 165/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0732 - accuracy: 0.9819
# Epoch 166/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0731 - accuracy: 0.9819
# Epoch 167/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0731 - accuracy: 0.9819
# Epoch 168/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0730 - accuracy: 0.9819
# Epoch 169/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0728 - accuracy: 0.9819
# Epoch 170/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0729 - accuracy: 0.9819
# Epoch 171/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0727 - accuracy: 0.9819
# Epoch 172/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0726 - accuracy: 0.9819
# Epoch 173/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0726 - accuracy: 0.9819
# Epoch 174/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0725 - accuracy: 0.9819
# Epoch 175/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0724 - accuracy: 0.9819
# Epoch 176/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0723 - accuracy: 0.9819
# Epoch 177/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 0.9819
# Epoch 178/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0722 - accuracy: 0.9819
# Epoch 179/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0722 - accuracy: 0.9819
# Epoch 180/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0721 - accuracy: 0.9819
# Epoch 181/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0720 - accuracy: 0.9819
# Epoch 182/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0720 - accuracy: 0.9819
# Epoch 183/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0719 - accuracy: 0.9819
# Epoch 184/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0718 - accuracy: 0.9819
# Epoch 185/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0718 - accuracy: 0.9819
# Epoch 186/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0717 - accuracy: 0.9819
# Epoch 187/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0716 - accuracy: 0.9819
# Epoch 188/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0716 - accuracy: 0.9833
# Epoch 189/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0715 - accuracy: 0.9847
# Epoch 190/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0714 - accuracy: 0.9847
# Epoch 191/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0713 - accuracy: 0.9819
# Epoch 192/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0713 - accuracy: 0.9819
# Epoch 193/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0712 - accuracy: 0.9819
# Epoch 194/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0711 - accuracy: 0.9833
# Epoch 195/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0711 - accuracy: 0.9819
# Epoch 196/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0710 - accuracy: 0.9833
# Epoch 197/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0709 - accuracy: 0.9819
# Epoch 198/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0708 - accuracy: 0.9819
# Epoch 199/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0708 - accuracy: 0.9833
# Epoch 200/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0707 - accuracy: 0.9833

# %%
test_loss, test_acc = my_model.evaluate(X_test, y_test)
# Out:
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0992 - accuracy: 0.9650

# %%
test_loss, test_acc = my_model.evaluate(X_val, y_val)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.0820 - accuracy: 0.9625

# %% [markdown]
# - - -
# ## 3. IMPLEMENTING YOUR OWN SIMPLE NEURAL NETWORK
#
# Now that you see how the standard library ANN performs on the XOR dataset, you will attempt to implement your own version of the neural network. To help you, a template has been created including the backpropagation. Essensially, you will get the backward gradients for free. However, please note that the backprop implementation assume usage of tanh activation for the hidden layer and softmax for the output layer. There are some subtasks which you need to implement in order to get the network to work properly.

# %%
from numpy.lib.function_base import average
from pickle import NONE
from sklearn.base import BaseEstimator
from sklearn.preprocessing import OneHotEncoder

class MyNeuralNet(BaseEstimator):
    """Your implementation of a simple neural network"""

    def __init__ (self, n0, n1, n2, alpha=0.01):
        """
        @param: n0: Number of nodes in the input layer
        @param: n1: Number of nodes in the hidden layer
        @param: n2: Number of nodes in the output layer
        @param: alpha: The Learning Rate
        """
        self.input = n0
        self.hidden = n1
        self.output = n2
        # SUBTASK 1: Initialize the parameters to random values.
        np.random.seed(42)
        self.W1 = np.random.rand(self.hidden, self.input)
        self.b1 = np.random.rand(self.hidden, 1)
        self.W2 = np.random.rand(self.output, self.hidden)
        self.b2 = np.random.rand(self.output, 1)


        # self.W1 = np.random.normal(size = (self.hidden, self.input))
        # self.b1 = np.random.normal(self.hidden, 1)
        # self.W2 = np.random.normal(size = (self.output, self.hidden))
        # #print(self.W2.shape)
        # self.b2 = np.random.normal(self.output, 1)
        
        # Configure the learning rate
        self.alpha = alpha
        # One-hot encoder for labels
        self.encoder = OneHotEncoder(sparse=False)
    
    # def tanh_act(self, X):
    #     return ((2 / 1 + np.exp(-2*X)) - 1)

    def softmax(self, X):
        return (np.exp(X) / np.sum(np.exp(X), axis=0))

    def forward_pass(self, X):
        """
        Pass the signal forward through the layers.
        @param: X: feature
        @return: A1: saved value of the output of the hidden layer
        @return: A2: activated return value of the output layer.
        """
        # SUBTASK 2: Implement Forward propagation.
        # Note: that you must implement tanh activation for the hiden layer 
        # and softmax for the output layer
        

        Z1 = np.dot(self.W1, X) + self.b1
        #A1 = self.tanh_act(Z1)
        A1 = np.tanh(Z1)
        Z2 = np.dot(self.W2, A1) + self.b2
        A2 = self.softmax(Z2)
        
        return A1, A2 


    def loss(self, X, y):
        """
        Evaluate the total loss on the dataset
        @param: X: features
        @param: y: labels
        @return: L: the loss value
        """
        

        # SUBTASK 3: Calculate the loss using Cross-Entropy
        # You will need to return the average loss on the data
        # Hint: Use A2 to calculate the loss
        A1, A2 = self.forward_pass(X)  
        # Another Hint: First, you may want to convert the lable y into a one-hot vector
        Y = self.one_hot(y)
        # lecture pg54
        L = -1*np.sum(Y*np.log(A2))
        #print(L)
        return L

    def backward_pass(self, A1, A2, X, y):
        """
        @param: X: feature
        @param: y: label
        @param: A1: saved value of the output of the hidden layer
        @param: a2: activated return value of the output layer.

        @return: dW1: the loss gradient of W1
        @return: db1: the loss gradient of b1
        @return: dW2: the loss gradient of W2
        @return: db2: the loss gradient of b2
        """

        # You DO NOT CHANGE this function, ...
        # unless you are advanced and want to use different activation function for your forward pass
        # This is an elegant partial derivative of cross entropy with softmax
        # Ref document: https://deepnotes.io/softmax-crossentropy
        m   = y.shape[0]
        dZ2 = A2 - self.one_hot(y)
        dW2 = np.dot(dZ2, A1.T)/m
        #print(dW2.shape)
        db2 = np.sum(dZ2, axis=1, keepdims=True)/m
        dZ1 = np.multiply(np.dot( self.W2.T, dZ2), 1-np.power(A1, 2))
        dW1 = np.dot(dZ1, X.T)/m
        db1 = np.sum(dZ1, axis=1, keepdims=True)/m

        return dW1, db1, dW2, db2


    def fit(self, X, y , epochs, X_val, Y_val):
        """
        Learns parameters for the neural network and returns the model.
        
        @param: X: the training feature
        @param: y: the train label
        @param: epochs: Number of passes through the training data for gradient descent
        @param: X_val: the feature of validation set
        @param: y_val: the label of validation set
        """

        # Input checks: X and X_val needs to be in the form of n0 x m
        if (X.shape[0] > X.shape[1]): X = X.T
        if (X_val.shape[0] > X_val.shape[1]): X_val = X_val.T

        # Gradient descent
        for i in range(0, epochs):
            
            # SUBTASK 4: Compute the forward, backward, and gradient descent parameter update
            # Step 1: Forward pass
            A1, A2 = self.forward_pass(X)  
            
            # Step 2: Backward pass
            dW1, db1, dW2, db2 = self.backward_pass(A1, A2, X, y)

            # Step 3: Gradient Descent 
            #print(dW2.shape)
            #print(self.W2.shape)
            self.W1 = self.W1 - self.alpha * dW1  #+
            self.b1 = self.b1 - self.alpha * db1
            self.W2 = self.W2 - self.alpha * dW2  #+
            self.b2 = self.b2 - self.alpha * db2

            # Print the loss and validation accuracy every 10 epochs.
            if i % 10 == 0:
                print("Epoch %i/%i - loss: %f - accuracy: %f - val_loss: %f - val_accuracy: %f" 
                      %(i,epochs, self.loss(X, y), self.evaluate(X, y),
                        self.loss(X_val, y_val), self.evaluate(X_val,y_val)))
        #print(self.W1, self.b1, self.W2, self.b2)
                
  #row 0 chance for getting 0, row 1 chance for getting 1
    def predict(self, X):
        """
        Predict label vector y
        """
        # check X for the form of n0 x m
        if (X.shape[0] > X.shape[1]): X = X.T
        
        # SUBTASK 5: Implement the prediction process. 
        # Hint: It should include a forward pass, and then use the class with higher probability.
        A1, A2 = self.forward_pass(X)
        #temp = np.array(A1, A2)
        #print("Start")
        #print(A2)
        #print("End")
        y_hat = []
        #temp = np.argmax(A2)
        temp = A2.shape[1]
        #print("A2shape:" , A2.shape[1])
        for i in range(temp):
          if A2[0][i] < A2[1][i]:
            y_hat.append(1)
          else:
            y_hat.append(0)
        y_hat = np.array(y_hat)
        return y_hat


    def evaluate(self, X, y):
        """
        Evaluate the accuracy of the model
        """
        m = y.shape[0]
        y_hat = self.predict(X)
        correct_y = (y_hat == y).astype(int)

        return sum(correct_y)/m


    def one_hot(self, y):
        """
        Utility function: Convert a label vector to one-hot vector
        """
        Y = self.encoder.fit_transform(y.reshape(len(y),1))  
        return Y.T # Transpose to get into same shape 1 x m


    def plot_decision_boundary(self, X, y):
        """
        Utility Function: Plot a decision boundary for visualization purpose.
        If you don't fully understand this function don't worry, it just generates the contour plot below.
        """
        # Set min and max values and give it some padding
        x_min, x_max = X[:,0].min() - .5, X[:,0].max() + .5
        y_min, y_max = X[:,1].min() - .5, X[:,1].max() + .5
        h = 0.01
        # Generate a grid of points with distance h between them
        xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
        # Predict the function value for the whole gid
        data_grid= np.c_[xx.ravel(), yy.ravel()]
        Z = self.predict(data_grid)
        Z = Z.reshape(xx.shape)

        # Plot the contour and training examples
        plt.contourf(xx, yy, Z, cmap=plt.cm.Pastel1)
        plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.Spectral)

# %% [markdown]
# ---
# ## 4. REFLECT ON THE COMPARISON BETWEEN YOUR IMPLEMENTATION TO THE STANDARD LIBRARY
# Now that you have implemented your own Neural Net class, let's use it! Create at least 3 instances of your Neural Net class, each with a different number of nodes in the hiden layer, tune it with the appropriate learning rate and number of iteration. You will test their performance in the Xor dataset and report the test accuracy metrics for each instance of your neural network.
#
# Based on the test accuracy, compare your models with the standard library version.

# %%
# MODEL 1 here
n0 = 2 # input layer dimensionality
n1 = 5 # hidden layer dimensionality
n2 = 2 # output layer dimensionality
alpha = 0.1 # learning rate for gradient descent
epochs = 1000 # number of iteration/epochs

# Build a model with 3 layers
myModel1 = MyNeuralNet(n0, n1, n2, alpha);
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

# Plot the decision boundary
myModel1.plot_decision_boundary(X_train, y_train);
# Out:
# Epoch 0/1000 - loss: 507.623777 - accuracy: 0.513889 - val_loss: 60.789395 - val_accuracy: 0.412500
# Epoch 790/1000 - loss: 90.006662 - accuracy: 0.981944 - val_loss: 10.831007 - val_accuracy: 0.950000
# Epoch 800/1000 - loss: 88.150192 - accuracy: 0.981944 - val_loss: 10.624002 - val_accuracy: 0.950000
# Epoch 810/1000 - loss: 86.390771 - accuracy: 0.981944 - val_loss: 10.427545 - val_accuracy: 0.950000
# Epoch 820/1000 - loss: 84.721705 - accuracy: 0.981944 - val_loss: 10.240924 - val_accuracy: 0.950000
# Epoch 830/1000 - loss: 83.136842 - accuracy: 0.981944 - val_loss: 10.063482 - val_accuracy: 0.950000
# Epoch 840/1000 - loss: 81.630522 - accuracy: 0.981944 - val_loss: 9.894618 - val_accuracy: 0.950000
# Epoch 850/1000 - loss: 80.197535 - accuracy: 0.981944 - val_loss: 9.733773 - val_accuracy: 0.950000
# Epoch 860/1000 - loss: 78.833083 - accuracy: 0.981944 - val_loss: 9.580436 - val_accuracy: 0.950000
# Epoch 870/1000 - loss: 77.532740 - accuracy: 0.981944 - val_loss: 9.434134 - val_accuracy: 0.950000
# Epoch 880/1000 - loss: 76.292424 - accuracy: 0.981944 - val_loss: 9.294429 - val_accuracy: 0.950000
# Epoch 890/1000 - loss: 75.108368 - accuracy: 0.981944 - val_loss: 9.160918 - val_accuracy: 0.950000
# Epoch 900/1000 - loss: 73.977085 - accuracy: 0.981944 - val_loss: 9.033227 - val_accuracy: 0.950000
# Epoch 910/1000 - loss: 72.895355 - accuracy: 0.981944 - val_loss: 8.911011 - val_accuracy: 0.950000
# Epoch 920/1000 - loss: 71.860192 - accuracy: 0.981944 - val_loss: 8.793948 - val_accuracy: 0.950000
# Epoch 930/1000 - loss: 70.868831 - accuracy: 0.981944 - val_loss: 8.681742 - val_accuracy: 0.950000
# Epoch 940/1000 - loss: 69.918708 - accuracy: 0.981944 - val_loss: 8.574116 - val_accuracy: 0.950000
# Epoch 950/1000 - loss: 69.007442 - accuracy: 0.981944 - val_loss: 8.470814 - val_accuracy: 0.950000
# Epoch 960/1000 - loss: 68.132819 - accuracy: 0.981944 - val_loss: 8.371598 - val_accuracy: 0.950000
# Epoch 970/1000 - loss: 67.292782 - accuracy: 0.981944 - val_loss: 8.276245 - val_accuracy: 0.950000
# Epoch 980/1000 - loss: 66.485416 - accuracy: 0.981944 - val_loss: 8.184549 - val_accuracy: 0.950000
# Epoch 990/1000 - loss: 65.708934 - accuracy: 0.981944 - val_loss: 8.096316 - val_accuracy: 0.950000
# Accuracy on the test set is  0.965

# %%
# MODEL 2 here
n0 = 2 # input layer dimensionality
n1 = 10 # hidden layer dimensionality
n2 = 2 # output layer dimensionality
alpha = 0.1 # learning rate for gradient descent
epochs = 1000 # number of iteration/epochs

# Build a model with 3 layers
myModel1 = MyNeuralNet(n0, n1, n2, alpha);
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

# Plot the decision boundary
myModel1.plot_decision_boundary(X_train, y_train);
n2 = 2 # output layer dimensionality
alpha = 0.1 # learning rate for gradient descent
epochs = 500 # number of iteration/epochs

# Build a model with 3 layers
myModel1 = MyNeuralNet(n0, n1, n2, alpha);
myModel1.fit(X_train, y_train, epochs, X_val, y_val)
print("Accuracy on the test set is ", myModel1.evaluate(X_test, y_test))

# Plot the decision boundary
myModel1.plot_decision_boundary(X_train, y_train);
# Out:
# Epoch 0/500 - loss: 523.713720 - accuracy: 0.466667 - val_loss: 60.682544 - val_accuracy: 0.400000
# Epoch 10/500 - loss: 501.117307 - accuracy: 0.483333 - val_loss: 55.119642 - val_accuracy: 0.512500
# Epoch 20/500 - loss: 494.384829 - accuracy: 0.634722 - val_loss: 54.529521 - val_accuracy: 0.775000
# Epoch 30/500 - loss: 488.290721 - accuracy: 0.691667 - val_loss: 54.000697 - val_accuracy: 0.750000
# Epoch 40/500 - loss: 482.544763 - accuracy: 0.700000 - val_loss: 53.490477 - val_accuracy: 0.725000
# Epoch 50/500 - loss: 476.933989 - accuracy: 0.677778 - val_loss: 52.980765 - val_accuracy: 0.725000
# Epoch 60/500 - loss: 471.295945 - accuracy: 0.672222 - val_loss: 52.457067 - val_accuracy: 0.712500
# Epoch 70/500 - loss: 465.500890 - accuracy: 0.670833 - val_loss: 51.906805 - val_accuracy: 0.712500
# Epoch 80/500 - loss: 459.437534 - accuracy: 0.655556 - val_loss: 51.317888 - val_accuracy: 0.712500
# Epoch 90/500 - loss: 453.000247 - accuracy: 0.647222 - val_loss: 50.677355 - val_accuracy: 0.687500
# Epoch 100/500 - loss: 446.078178 - accuracy: 0.650000 - val_loss: 49.970291 - val_accuracy: 0.687500
# Epoch 110/500 - loss: 438.548929 - accuracy: 0.652778 - val_loss: 49.179446 - val_accuracy: 0.700000
# Epoch 120/500 - loss: 430.280633 - accuracy: 0.663889 - val_loss: 48.286101 - val_accuracy: 0.700000
# Epoch 130/500 - loss: 421.146049 - accuracy: 0.691667 - val_loss: 47.272655 - val_accuracy: 0.700000
# Epoch 140/500 - loss: 411.049510 - accuracy: 0.786111 - val_loss: 46.126973 - val_accuracy: 0.775000
# Epoch 150/500 - loss: 399.960352 - accuracy: 0.861111 - val_loss: 44.847483 - val_accuracy: 0.875000
# Epoch 160/500 - loss: 387.936109 - accuracy: 0.902778 - val_loss: 43.446488 - val_accuracy: 0.887500
# Epoch 170/500 - loss: 375.115835 - accuracy: 0.934722 - val_loss: 41.948724 - val_accuracy: 0.925000
# Epoch 180/500 - loss: 361.681885 - accuracy: 0.951389 - val_loss: 40.384867 - val_accuracy: 0.937500
# Epoch 190/500 - loss: 347.816209 - accuracy: 0.959722 - val_loss: 38.783863 - val_accuracy: 0.950000
# Epoch 200/500 - loss: 333.679837 - accuracy: 0.962500 - val_loss: 37.168777 - val_accuracy: 0.975000
# Epoch 210/500 - loss: 319.417540 - accuracy: 0.962500 - val_loss: 35.557066 - val_accuracy: 0.975000
# Epoch 220/500 - loss: 305.169367 - accuracy: 0.965278 - val_loss: 33.962868 - val_accuracy: 0.975000
# Epoch 490/500 - loss: 105.229261 - accuracy: 0.970833 - val_loss: 12.180641 - val_accuracy: 0.962500
# Accuracy on the test set is  0.965

# %%
# COMPARISONS WITH THE STANDARD LIBRARY

# %% [markdown]
# Standard Library with batch size: 100, epochs: 200:
#
# 	Train set: highet accuracy is 0.9833, loss of 0.0707
#
# 	Validation set: highet accuracy is 0.9625, loss of 0.0820
#
# 	Test set: accuracy: 0.9650
#
# My model1 with n0=2, n1=5, n2=2, alpha=0.1, epochs=1000:
#
# 	Train set: highet accuracy is 0.981944, loss of 65.708
#
# 	Validation set: highet accuracy is 0.9500, loss of 8.0963
#
# 	Test set: accuracy: 0.9650
#
# My model2 with n0=2, n1=10, n2=2, alpha=0.1, epochs=1000:
#
# 	Train set: highet accuracy is 0.981944, loss of 62.0437
#
# 	Validation set: highet accuracy is 0.9625, loss of 8.1778
#
# 	Test set: accuracy: 0.9750
#
# My model3 with n0=2, n1=15, n2=2, alpha=0.1, epochs=1000:
#
# 	Train set: highet accuracy is 0.9792, loss of 57.5019
#
# 	Validation set: highet accuracy is 0.9750, loss of 6.8498
#
# 	Test set: accuracy: 0.9650
#
# My model4 with n0=2, n1=10, n2=2, alpha=0.01, epochs=1000:
#
# 	Train set: highet accuracy is 0.6667, loss of 468.1817
#
# 	Validation set: highet accuracy is 0.7375, loss of 52.1038
#
# 	Test set: accuracy: 0.6850
#
# My model5 with n0=2, n1=10, n2=2, alpha=0.1, epochs=1500:
#
# 	Train set: highet accuracy is 0.9833, loss of 42.7553
#
# 	Validation set: highet accuracy is 0.9625, loss of 5.9201
#
# 	Test set: accuracy: 0.9700
#
# My model6 with n0=2, n1=10, n2=2, alpha=0.1, epochs=500:
#
# 	Train set: highet accuracy is 0.9708, loss of 105.2293
#
# 	Validation set: highet accuracy is 0.9625, loss of 12.1806
#
# 	Test set: accuracy: 0.9650

# %% [markdown]
# ## Reflection
# Write at least a paragraph answering these prompts: How did your own network perform? Is there any major differences between the implementations? Finally, reflecting on your experience implementing a learning algorithm for this assignment (Was it hard/easy/fun?, From which part did you learn the most?)!

# %% [markdown]
# For the train set, my model5 and standard library are the ones have the same highest accuracy of 0.9833. For the validation set, my model3 has the highest accuracy of 0.9750. For the test set, my model2 has the highest accuracy of 0.9750. It is a little surprising that different models have different performances due to different hyperparameters. Overall, the assignment itself is fun with the different tryout results. The part I learn the most is that with the epoch of 10, none of my models will work, and all their accuracy is 0.

# %% [markdown]
# ---
# # Get Help?
# In case you get stuck in any step in the process, you may find some useful information from:
#
#  * Consult my [lecture 13](https://docs.google.com/presentation/d/1otQfmMomWctLZKI3hHKAA4lLkbXFtagLaQov8gNh4LI/edit?usp=sharing) and [Colab Notebook 10](https://colab.research.google.com/drive/1x5biI3dP5YvvDEI0wapJcSgQNnATDzNe)
#  * Talk to the TA, they are available and there to help you during office hour.
#  * Come talk to me or email me <nn4pj@virginia.edu> with subject starting "CS4774 Assignment 4:...".
#
# Part of the codes used in this assignment is modified from Konstantinos Kitsios under the 3-Clause BSD License. Best of luck and have fun!
